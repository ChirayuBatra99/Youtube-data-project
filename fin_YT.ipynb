# %%
import csv
import requests
file=open('YT.csv','w')
fields=["Title","id","views","likes"]
csvwriter = csv.writer(file)
csvwriter.writerow(fields)
# Out:
# 22

# %%
url = input()
data = requests.get(url).text

sp=data.split("externalId")[-1]
x=sp.split('"')[2]
c=0
sp2=data

def vidos():
  global sp2
  sp2=sp2.split("simpleText")[-1]
  y=sp2.split('"')[2]
  print(y)


vidos()
print(x)
# Out:
# https://www.youtube.com/channel/UCIwFjwMjI0y7PDBVEO9-bkQ
# 71.1M subscribers
# UCIwFjwMjI0y7PDBVEO9-bkQ

# %%
uu='https://www.googleapis.com/youtube/v3/playlists?part=snippet&channelId='+x+'&key=AIzaSyC2TLvpySg_tpUsqZ_xeEDLmENhRJLDtSY'
ne=requests.get(uu).json()['items'][0]['id']
print(ne)

uu1='https://www.googleapis.com/youtube/v3/channels?id='+x+'&key=AIzaSyC2TLvpySg_tpUsqZ_xeEDLmENhRJLDtSY&part=contentDetails'
ne=requests.get(uu1).json()
print(ne)
uk=ne['items'][0]['contentDetails']['relatedPlaylists']['uploads']
print(uk)
# Out:
# PLsifFPg4DahKxuAQ7JiWSucnx9Q4pl5Ox
# {'kind': 'youtube#channelListResponse', 'etag': 'DqjsQbz3QeWCw3K4nMODzDqKV88', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'PwB2Xs_60ENAwuu4yt9sQ3GomdA', 'id': 'UCIwFjwMjI0y7PDBVEO9-bkQ', 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUIwFjwMjI0y7PDBVEO9-bkQ'}}}]}
# UUIwFjwMjI0y7PDBVEO9-bkQ

# %%
uu='https://www.googleapis.com/youtube/v3/playlistItems?playlistId='+uk+'&key=AIzaSyC2TLvpySg_tpUsqZ_xeEDLmENhRJLDtSY&part=snippet&maxResults=50'
ne1=requests.get(uu).json()
print(ne1)

for jjj in range(50):
  uk2=ne1['items'][jjj]['snippet']['title']
  videoid=ne1['items'][jjj]['id']
  print(uk2)
  #print(videoid)
  uu6='https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=Jr4O5-TfN3U&key=AIzaSyC2TLvpySg_tpUsqZ_xeEDLmENhRJLDtSY'
  ne4=requests.get(uu6).json()
  view=ne4['items'][0]['statistics']['viewCount']
  like=ne4['items'][0]['statistics']['likeCount']
  row=[uk2,videoid,view,like]
  csvwriter.writerow(row)

file.close()
# Out:
# {'kind': 'youtube#playlistItemListResponse', 'etag': '3FDzy7VA63jeBaPmUt2jU1w2hUw', 'nextPageToken': 'EAAaBlBUOkNESQ', 'items': [{'kind': 'youtube#playlistItem', 'etag': 'WF_i8XylT_DbclCrqQt3VpzDS4I', 'id': 'VVVJd0Zqd01qSTB5N1BEQlZFTzktYmtRLno1QUlNRjFCak9F', 'snippet': {'publishedAt': '2022-11-21T16:29:07Z', 'channelId': 'UCIwFjwMjI0y7PDBVEO9-bkQ', 'title': 'Drew House TOKYO #shorts', 'description': 'Follow Justin: \nhttp://facebook.com/justinbieber\nhttp://twitter.com/justinbieber\nhttp://instagram.com/justinbieber\n \nSign up for Justin’s newsletter: http://justinbiebermusic.com\n\n#JustinBieber', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/z5AIMF1BjOE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/z5AIMF1BjOE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/z5AIMF1BjOE/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/z5AIMF1BjOE/sddefault.jpg', 'width':
# ...
